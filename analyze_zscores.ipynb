# %%
import pandas as pd
from cmapPy.pandasGEXpress import parse

# %%
filepath = 'GSE70138_Level5.gctx'
siginfopath = "GSE70138_Broad_LINCS_sig_info_2017-03-06.txt"
geneinfopath = 'GSE70138_Broad_LINCS_gene_info_2017-03-06.txt'
pertinfopath = 'GSE70138_Broad_LINCS_pert_info_2017-03-06.txt'
instinfopath = 'GSE70138_Broad_LINCS_inst_info_2017-03-06.txt'
sigmetricsinfopath = 'GSE70138_Broad_LINCS_sig_metrics_2017-03-06.txt'

# %%
# Read in signature info
sig_info = pd.read_csv(siginfopath, sep="\t")

# Get the signatures associated with gene knockdown?
gene_info = sig_info['sig_id'][sig_info['pert_type'] == 'trt_xpr']
len(gene_info)
# Out:
# 3882

# %%
sig_info.pert_type.unique()
# Out:
# array(['ctl_vehicle', 'trt_cp', 'trt_xpr', 'ctl_untrt', 'ctl_vector'], dtype=object)

# %%
# Get the data for the gene signatures
gene_only_gctoo = parse(filepath, cid=gene_info, convert_neg_666=True)

# TODO: What are the rows? Gene expression across signatures? If so, how to match row to gene?
gene_only_gctoo.data_df
# Out:
# cid        XPR002_A375.311_96H:A03  XPR002_A375.311_96H:A05  \
# rid
# 780                       0.243866                -0.952937
# 7849                     -0.859044                -0.350283
# 2978                      0.168806                -0.185938
# 2049                     -0.888603                -0.138565
# 2101                     -0.171990                 1.637886
# 8717                     -0.189519                -0.419083
# 10594                    -0.218713                 0.076149
# 826                      -0.216501                 0.140967
# 11224                     0.596947                 0.298314
# 6158                      0.255760                -1.220641
# 1982                      0.226302                -0.880475
# 8664                      0.724440                -0.167706
# 11315                     0.908071                 0.107076
# 6727                     -0.129463                 0.330619
# 2665                      0.952892                 0.479612
# 6135                      1.085979                -0.571732
# 6144                      1.018969                 0.187139
# 6152                      1.458210                -0.952225
# 4735                      0.074140                 1.103961
# 6233                      1.181907                 0.392558
# 6207                      1.075251                 0.292019
# 2197                      0.474206                 0.263579
# 1072                      0.906228                 0.356325
# 6141                      0.224947                -0.710484
# 8665                      0.614941                 0.912916
# 6193                      0.553925                -0.994150
# 6155                      0.801594                 0.249642
# 6164                      0.933507                -0.263980
# 4677                     -0.345442                -0.205867
# 56910                     0.221173                 0.655132
# ...                            ...                      ...
# 55589                     0.024092                 0.418288
# 376267                   -0.868918                 1.403632
# 55662                    -0.484257                -0.132837
# 79890                     0.681465                 1.943969
# 84820                    -0.440601                -0.419069
# 2931                     -0.228509                 0.577533
# 63876                    -0.603529                 0.573176
# 5526                     -0.122446                 1.224837
# 91860                    -0.479663                 0.073227
# 51275                    -0.562696                -0.820055
# 57175                    -0.698701                -0.789276
# 126298                   -0.820332                 1.109679
# 158747                   -1.126534                 0.235070
# 64748                    -0.168834                -1.235618
# 78992                     0.164027                 0.256386
# 63897                     1.161737                 0.125884
# 85002                     0.797043                 0.780163
# 283232                   -0.020235                 0.451864
# 25960                    -0.310330                -0.849773
# 89941                     0.114540                 2.263247
# 79874                     0.049542                 0.218173
# 100289678                -0.195813                 2.268417
# 6376                     -0.681177                -0.533758
# 79716                     0.686707                 0.426130
# 11033                    -1.012669                -1.077916
# 4034                      0.982363                 1.527788
# 399664                   -0.329244                -0.657076
# 54869                    -0.986245                -0.141220
# 90379                     0.594245                -0.448896
# 60                        0.614292                -0.485147
#
# cid        XPR002_A375.311_96H:A06  XPR002_A375.311_96H:A07  \
# rid
# 780                      -0.446545                 0.112903
# 7849                     -0.886214                -0.548320
# 2978                      0.057624                -0.082399
# 2049                     -0.071002                -0.203572
# 2101                     -0.478066                 0.044470
# 8717                     -0.039338                -0.023531
# 10594                     0.044426                 0.394580
# 826                      -0.482613                -0.529891
# 11224                     1.249847                -0.264572
# 6158                      0.923278                 0.492669
# 1982                      0.131114                 0.645602
# 8664                     -0.408246                -0.170505
# 11315                    -0.293099                 0.258791
# 6727                     -0.508110                -0.265274
# 2665                     -0.004388                 0.409900
# 6135                      0.281290                 0.279420
# 6144                      0.831017                 0.141158
# 6152                      0.858452                -0.165803
# 4735                      1.013307                -0.651915
# 6233                      0.782476                 0.081328
# 6207                      1.113794                 0.497750
# 2197                      1.138423                 0.663903
# 1072                      0.546246                 0.233215
# 6141                      0.197134                -0.115572
# 8665                      1.529675                 0.399509
# 6193                      0.247048                -0.342342
# 6155                      1.014862                 0.065239
# 6164                      1.256351                 0.274860
# 4677                     -0.114314                 0.794500
# 56910                    -0.391237                 0.114653
# ...                            ...                      ...
# 55589                     0.469379                -0.176858
# 376267                   -1.299871                -0.401324
# 55662                     0.566732                 0.330311
# 79890                     1.358527                 0.297536
# 84820                    -0.025384                -0.206997
# 2931                      0.628208                -0.795624
# 63876                    -0.622628                -0.216517
# 5526                     -0.884280                 0.547939
# 91860                    -0.300082                -0.726990
# 51275                     0.692056                -0.828853
# 57175                     0.467269                 0.617752
# 126298                   -0.157862                -0.861840
# 158747                    0.426516                -0.468918
# 64748                    -0.819504                -0.427962
# 78992                    -0.224519                -0.410002
# 63897                    -0.003439                 0.266486
# 85002                    -1.954953                 1.520115
# 283232                    0.409292                 0.360243
# 25960                    -0.408866                 0.242441
# 89941                     0.389420                 0.532153
# 79874                    -0.403435                 0.320493
# 100289678                 0.082890                 0.108866
# 6376                     -0.746044                -0.513026
# 79716                     1.770363                -0.248771
# 11033                    -0.942191                -0.015516
# 4034                      0.692546                 0.278478
# 399664                   -0.647386                -0.860224
# 54869                    -1.529425                 0.063729
# 90379                    -0.455355                -0.267909
# 60                        0.409948                -0.609091
#
# cid        XPR002_A375.311_96H:A08  XPR002_A375.311_96H:A09  \
# rid
# 780                      -1.310640                -0.275045
# 7849                     -0.945945                 0.168500
# 2978                     -0.128004                -0.065750
# 2049                     -0.828164                 0.099511
# 2101                     -0.372838                 0.489055
# 8717                      0.001557                -0.913561
# 10594                     1.141021                -0.293737
# 826                       0.429554                 1.172715
# 11224                    -0.874396                 0.440808
# 6158                     -1.202152                 1.311242
# 1982                     -0.483656                -0.484690
# 8664                      0.406645                -0.901628
# 11315                    -1.389989                 0.172677
# 6727                      0.134811                 0.320010
# 2665                      0.024232                 0.253085
# 6135                     -1.372046                -0.164593
# 6144                     -1.006811                 0.998082
# 6152                     -1.554402                -0.334768
# 4735                      0.514737                -0.221291
# 6233                     -0.543614                 0.433851
# 6207                     -1.143846                 0.892601
# 2197                     -0.807090                 0.837254
# 1072                     -0.600706                 0.403487
# 6141                     -1.821642                 0.469759
# 8665                     -0.356061                 0.312714
# 6193                     -4.416692                 0.308149
# 6155                     -1.015064                 0.726627
# 6164                     -1.023752                -0.085676
# 4677                      0.395598                -0.102536
# 56910                    -0.033842                 0.676357
# ...                            ...                      ...
# 55589                    -1.638014                 0.215978
# 376267                   -0.569898                 0.168369
# 55662                    -0.025657                 0.185508
# 79890                    -1.163639                -0.820472
# 84820                     0.396407                -0.357699
# 2931                     -0.699512                 0.439064
# 63876                    -0.488018                 0.478813
# 5526                     -1.115582                 0.654115
# 91860                    -0.009907                 0.669221
# 51275                     0.130731                -0.043185
# 57175                    -0.968135                 0.628954
# 126298                   -0.109734                -1.272006
# 158747                   -0.581054                -0.502160
# 64748                    -0.363789                 0.715987
# 78992                     0.165734                 0.453882
# 63897                    -0.682028                 0.249286
# 85002                     0.095504                -0.247176
# 283232                    1.162894                 0.038773
# 25960                     0.462132                 0.659136
# 89941                     0.532273                 0.774676
# 79874                     0.495525                 1.475657
# 100289678                -0.013384                -1.785184
# 6376                      0.082204                 0.509916
# 79716                    -0.191877                 0.173015
# 11033                    -0.639149                -0.323036
# 4034                      0.690911                 0.392891
# 399664                   -0.513231                 0.328283
# 54869                    -0.836670                -0.906830
# 90379                     0.333111                -0.060432
# 60                       -0.392123                 0.196693
#
# cid        XPR002_A375.311_96H:A10  XPR002_A375.311_96H:A11  \
# rid
# 780                      -0.732965                 2.022038
# 7849                     -0.198566                -0.900533
# 2978                      0.774338                 0.016237
# 2049                     -0.715788                -0.281149
# 2101                      0.373023                -0.146923
# 8717                     -0.646333                 0.662979
# 10594                     0.340027                -0.161252
# 826                       0.244577                 1.436421
# 11224                    -0.561465                -0.562671
# 6158                     -0.117571                -0.034405
# 1982                     -0.178853                 0.596868
# 8664                      0.336037                -0.210351
# 11315                    -0.327386                -0.356609
# 6727                      0.151339                 0.316599
# 2665                      0.637547                -0.502171
# 6135                     -0.400294                -0.061735
# 6144                     -0.572116                 0.091063
# 6152                     -0.780788                 0.096056
# 4735                     -0.126698                 0.826715
# 6233                     -0.280884                 0.445093
# 6207                     -0.135499                 1.155849
# 2197                     -0.208997                -0.087993
# 1072                     -0.875336                 1.161609
# 6141                     -0.877076                -0.185335
# 8665                     -0.188722                 1.532151
# 6193                     -1.255688                 0.829702
# 6155                     -1.097681                 0.810025
# 6164                     -0.388065                 1.025623
# 4677                     -0.394101                -0.592604
# 56910                    -0.410337                 0.489237
# ...                            ...                      ...
# 55589                     0.499751                 0.615034
# 376267                    0.136389                -0.646277
# 55662                    -0.638379                 0.008592
# 79890                    -0.110436                 0.778025
# 84820                    -0.683221                -0.663321
# 2931                     -0.241437                -0.472403
# 63876                     1.230832                -0.068439
# 5526                      0.692210                 0.221682
# 91860                     0.230673                 0.749857
# 51275                     0.738961                -0.826472
# 57175                    -0.454843                 1.367156
# 126298                    0.392516                -1.234285
# 158747                    0.338157                -0.644709
# 64748                     0.840145                 0.077987
# 78992                     0.690859                 0.122115
# 63897                     0.812376                -0.876351
# 85002                    -0.800814                -1.191733
# 283232                    0.063322                 1.205562
# 25960                    -0.746945                -0.709125
# 89941                    -0.862785                -0.578584
# 79874                    -0.455126                -0.436877
# 100289678                -0.834099                -0.729940
# 6376                      0.243050                 0.547456
# 79716                    -0.255006                 0.339351
# 11033                     0.068093                -1.033460
# 4034                      0.539606                 0.493085
# 399664                    0.104908                 1.087932
# 54869                    -0.580087                -0.662748
# 90379                     0.253607                -0.912998
# 60                       -0.136460                 0.513912
#
# cid        XPR002_A375.311_96H:A12  XPR002_A375.311_96H:A13  \
# rid
# 780                      -1.069390                -0.820676
# 7849                     -0.134194                 0.956132
# 2978                      0.629270                -0.151840
# 2049                     -0.585926                 0.584033
# 2101                      0.753989                -0.033722
# 8717                      0.673124                -1.673453
# 10594                    -0.218486                 0.109525
# 826                      -0.810020                -0.200278
# 11224                    -0.138016                -1.084346
# 6158                      0.805016                -1.652849
# 1982                     -0.790161                 0.788876
# 8664                      0.260914                 0.116856
# 11315                     2.011813                -0.192967
# 6727                      0.378141                -0.385584
# 2665                     -0.724938                -0.834518
# 6135                      0.687994                -1.099879
# 6144                      0.241314                -1.532279
# 6152                      0.039034                -1.212202
# 4735                     -0.274559                 0.148406
# 6233                      0.164496                -0.465969
# 6207                     -0.387688                -0.837512
# 2197                      0.031730                -0.584105
# 1072                     -1.229803                -0.532104
# 6141                      0.281971                -2.120344
# 8665                     -1.422059                 0.431882
# 6193                     -0.618738                -3.839068
# 6155                     -0.621290                -1.562586
# 6164                     -0.893999                -1.079879
# 4677                     -1.702348                 0.039467
# 56910                    -0.382524                -0.214518
# ...                            ...                      ...
# 55589                    -0.108557                -1.300755
# 376267                    0.707121                -0.613174
# 55662                     1.262023                -0.622782
# 79890                     0.411678                -0.711176
# 84820                     0.877964                -0.044127
# 2931                      0.285924                -1.316119
# 63876                     1.096066                -0.165638
# 5526                      0.670543                 0.160212
# 91860                    -0.594511                -0.498807
# 51275                    -0.075376                -0.552320
# 57175                     0.057745                 0.253995
# 126298                    0.977237                 0.353969
# 158747                   -0.266048                -0.881172
# 64748                     1.348836                 0.073097
# 78992                    -0.168096                -0.006094
# 63897                     0.224464                 0.073842
# 85002                     0.419643                 0.714843
# 283232                   -0.316566                -0.478973
# 25960                    -0.210782                -0.510556
# 89941                     1.074315                -1.410046
# 79874                     0.687311                 0.821190
# 100289678                 0.919973                -0.122614
# 6376                     -0.770835                -0.052010
# 79716                     1.728991                -0.090729
# 11033                    -0.703517                -0.717029
# 4034                      1.543814                -0.408978
# 399664                   -0.705609                 0.229793
# 54869                     0.135008                 0.750626
# 90379                     0.447570                -0.024352
# 60                       -0.677580                 0.483036
#
# cid                 ...             XPR002_YAPC.311_96H:P24  \
# rid                 ...
# 780                 ...                           -0.345607
# 7849                ...                           -0.666881
# 2978                ...                           -1.193643
# 2049                ...                           -0.074385
# 2101                ...                           -0.426131
# 8717                ...                           -1.018990
# 10594               ...                            1.470283
# 826                 ...                           -0.301906
# 11224               ...                            0.809873
# 6158                ...                            0.882397
# 1982                ...                            0.458320
# 8664                ...                           -0.854454
# 11315               ...                           -0.201141
# 6727                ...                            1.327197
# 2665                ...                            0.209785
# 6135                ...                            1.256532
# 6144                ...                            1.287102
# 6152                ...                            0.206124
# 4735                ...                            0.824673
# 6233                ...                            0.937134
# 6207                ...                            1.266660
# 2197                ...                            0.992043
# 1072                ...                            1.014915
# 6141                ...                            0.502988
# 8665                ...                           -0.699556
# 6193                ...                            0.223974
# 6155                ...                            1.068701
# 6164                ...                            0.269530
# 4677                ...                           -0.988990
# 56910               ...                            0.152582
# ...                 ...                                 ...
# 55589               ...                           -1.028985
# 376267              ...                           -0.511990
# 55662               ...                           -1.306470
# 79890               ...                           -1.294551
# 84820               ...                            0.890866
# 2931                ...                           -1.448023
# 63876               ...                           -0.542725
# 5526                ...                           -0.911247
# 91860               ...                            0.763216
# 51275               ...                           -0.033705
# 57175               ...                           -0.585428
# 126298              ...                           -1.249373
# 158747              ...                           -0.027837
# 64748               ...                            0.319394
# 78992               ...                           -0.778671
# 63897               ...                           -1.498678
# 85002               ...                            0.150895
# 283232              ...                           -1.132299
# 25960               ...                           -1.295699
# 89941               ...                           -0.775261
# 79874               ...                           -1.149062
# 100289678           ...                           -0.014847
# 6376                ...                           -0.654404
# 79716               ...                           -1.476633
# 11033               ...                           -0.157621
# 4034                ...                            1.025249
# 399664              ...                            1.259545
# 54869               ...                           -0.775993
# 90379               ...                           -1.297810
# 60                  ...                            1.910441
#
# cid        XPR002_YAPC.311_96H:B23  XPR002_YAPC.311_96H:B24  \
# rid
# 780                        2.13755                 -0.78795
# 7849                       0.08970                 -0.42105
# 2978                      -0.30940                 -0.76915
# 2049                      -0.67430                 -0.11360
# 2101                       0.31635                 -0.23100
# 8717                      -0.06305                  0.16385
# 10594                      0.99315                 -1.55330
# 826                        1.66660                 -0.95980
# 11224                     -0.26955                  0.97660
# 6158                      -0.26430                  0.14930
# 1982                       0.74640                  0.85665
# 8664                      -0.07765                 -0.93580
# 11315                     -0.50520                 -0.42420
# 6727                       0.45610                  0.77880
# 2665                       0.44405                  1.22070
# 6135                      -0.14795                  0.51350
# 6144                      -0.31675                  1.14330
# 6152                      -0.49375                  0.35085
# 4735                      -0.08020                  0.94030
# 6233                      -0.78180                  0.92045
# 6207                      -0.20565                  0.44810
# 2197                      -0.22025                  0.09355
# 1072                      -0.24800                  0.04560
# 6141                      -0.36560                  0.38240
# 8665                      -0.81950                 -0.07620
# 6193                      -2.08230                  0.45135
# 6155                      -0.55740                  0.64375
# 6164                      -0.68225                  0.49995
# 4677                       0.45940                 -0.33085
# 56910                      0.01645                  1.07715
# ...                            ...                      ...
# 55589                     -0.70090                 -0.29220
# 376267                    -0.08220                 -0.06960
# 55662                      0.06230                  0.19845
# 79890                     -0.25190                 -0.24425
# 84820                      0.17450                  0.09180
# 2931                       0.23540                 -1.43955
# 63876                      0.32825                 -0.06355
# 5526                       0.46165                 -2.05385
# 91860                      0.61220                 -0.22300
# 51275                      0.56140                 -0.18620
# 57175                      1.06915                 -0.66420
# 126298                     0.86880                 -0.07740
# 158747                    -1.08315                 -0.04020
# 64748                      0.91310                 -0.59950
# 78992                     -0.85410                 -0.10035
# 63897                     -0.03380                  0.12810
# 85002                      0.59325                 -1.06575
# 283232                     0.07645                 -0.73000
# 25960                     -0.22445                 -0.38920
# 89941                      0.64995                 -0.40740
# 79874                      0.88835                 -1.81930
# 100289678                  0.40415                 -0.28740
# 6376                      -0.06880                  0.94940
# 79716                     -0.06495                 -2.10490
# 11033                     -0.84635                  0.80230
# 4034                       0.32990                  0.07195
# 399664                     0.36465                  0.81870
# 54869                     -0.89005                  0.39670
# 90379                     -0.34235                 -0.34165
# 60                         0.88590                  0.14075
#
# cid        XPR002_YAPC.311_96H:C24  XPR002_YAPC.311_96H:D21  \
# rid
# 780                       -0.72520                  0.15115
# 7849                      -0.67230                 -0.87715
# 2978                      -0.61540                 -0.44275
# 2049                      -0.19240                 -0.15885
# 2101                      -0.63850                 -0.08355
# 8717                       0.47790                 -0.47145
# 10594                      1.30840                  0.39390
# 826                       -0.77055                  0.50055
# 11224                     -0.02835                  0.36930
# 6158                      -0.56155                  0.21980
# 1982                       0.37430                 -0.44795
# 8664                      -0.48660                  0.10330
# 11315                      1.35300                  0.77930
# 6727                       0.73425                  0.75695
# 2665                       0.39025                 -0.17265
# 6135                      -0.67070                  0.42390
# 6144                      -0.83870                  0.60515
# 6152                      -0.60940                  0.61260
# 4735                      -0.45320                  0.47775
# 6233                      -0.59635                  0.67005
# 6207                      -0.45740                  0.34540
# 2197                       0.38660                 -0.01065
# 1072                      -0.29415                  1.15675
# 6141                      -0.18340                  0.11300
# 8665                      -0.41480                  0.23515
# 6193                      -2.22205                 -0.02370
# 6155                      -0.57180                  0.03175
# 6164                      -1.07295                  0.62790
# 4677                      -0.54715                  0.50935
# 56910                      0.46720                  0.38170
# ...                            ...                      ...
# 55589                      0.05725                  0.07335
# 376267                    -0.13520                 -0.02770
# 55662                     -0.55560                 -1.06000
# 79890                     -0.38350                  0.46215
# 84820                      1.03165                 -0.92210
# 2931                      -0.10115                 -1.55440
# 63876                      1.20375                  1.36655
# 5526                      -0.74040                  0.49385
# 91860                     -0.05820                 -0.07605
# 51275                      0.45350                  0.25295
# 57175                      0.37700                 -0.93675
# 126298                     0.30545                 -0.99405
# 158747                     2.15345                 -0.21345
# 64748                     -1.27790                 -0.04755
# 78992                     -0.43630                 -0.21425
# 63897                     -0.42505                 -0.04900
# 85002                     -0.10050                 -1.62400
# 283232                     0.16830                  0.98305
# 25960                     -0.53545                 -0.48145
# 89941                     -0.44550                 -0.65770
# 79874                     -0.13105                 -0.46695
# 100289678                  0.77470                  0.45240
# 6376                      -0.15355                 -0.17005
# 79716                     -1.11245                  0.44270
# 11033                     -0.18800                 -0.75395
# 4034                      -0.86955                  0.09030
# 399664                     1.76645                 -0.04970
# 54869                     -0.00900                 -0.27270
# 90379                     -1.21495                 -0.80485
# 60                        -0.00220                  0.44460
#
# cid        XPR002_YAPC.311_96H:F18  XPR002_YAPC.311_96H:G22  \
# rid
# 780                       -0.47000                  0.72245
# 7849                      -0.30765                  0.28190
# 2978                       1.00685                 -0.52470
# 2049                       0.99060                  0.34130
# 2101                      -1.34150                 -0.84365
# 8717                      -0.49080                  0.64420
# 10594                      1.58635                  0.79365
# 826                       -0.77170                  0.49635
# 11224                     -0.20830                 -0.25565
# 6158                       1.07655                  0.37980
# 1982                      -0.31920                 -0.30455
# 8664                       0.83205                 -0.54905
# 11315                      0.75415                  0.32660
# 6727                       0.75595                 -0.48920
# 2665                      -0.45425                 -0.36925
# 6135                       1.10570                  0.07025
# 6144                       0.95005                 -0.10245
# 6152                       0.54185                  0.10885
# 4735                       0.38065                 -0.36060
# 6233                       0.44710                  0.15655
# 6207                       1.14730                  0.36530
# 2197                       1.50160                  0.45605
# 1072                       1.61150                  0.31745
# 6141                       0.51390                 -0.28055
# 8665                      -0.20810                  0.61120
# 6193                       0.66615                 -1.19585
# 6155                       1.11990                 -0.00430
# 6164                       1.45960                  0.49575
# 4677                       0.78810                  0.75005
# 56910                     -0.02495                  1.69440
# ...                            ...                      ...
# 55589                     -0.05175                 -0.12905
# 376267                     0.95690                  0.40650
# 55662                      0.50375                  0.70400
# 79890                     -1.68950                  0.65655
# 84820                     -0.70595                 -0.81035
# 2931                       0.82955                  0.69335
# 63876                      0.15150                 -0.51795
# 5526                       1.25515                  1.05825
# 91860                     -0.73645                  0.23470
# 51275                      0.20885                 -1.02890
# 57175                      0.55130                  0.04685
# 126298                     0.27460                 -0.85595
# 158747                    -1.89845                 -0.90080
# 64748                      0.65855                 -0.37410
# 78992                      0.09995                 -0.31915
# 63897                     -0.92580                  0.18255
# 85002                     -0.45525                 -0.02140
# 283232                    -0.66180                  0.47155
# 25960                      0.11365                 -0.17380
# 89941                     -0.33150                 -0.37030
# 79874                      1.27600                  1.04720
# 100289678                  0.03265                  0.72930
# 6376                       0.29935                  0.42875
# 79716                      0.04210                  0.00445
# 11033                      0.18605                 -0.56315
# 4034                      -0.21860                  0.12635
# 399664                    -1.36800                 -1.17260
# 54869                     -0.29775                 -0.73400
# 90379                     -0.73595                  0.20495
# 60                         0.00625                 -0.62240
#
# cid        XPR002_YAPC.311_96H:G23  XPR002_YAPC.311_96H:M15  \
# rid
# 780                       -0.36960                 -1.04310
# 7849                      -0.62775                  0.64040
# 2978                      -0.37035                  1.09360
# 2049                       0.61855                 -0.03675
# 2101                      -0.40945                 -0.38430
# 8717                      -0.10210                  1.38515
# 10594                     -0.16120                 -0.40945
# 826                        0.25040                  0.61635
# 11224                     -1.45160                 -0.84940
# 6158                      -1.45255                 -0.98185
# 1982                       0.37240                 -1.26235
# 8664                      -1.20410                  0.83525
# 11315                     -0.57385                  0.81315
# 6727                      -0.56990                 -0.73690
# 2665                      -0.31940                 -0.04490
# 6135                      -1.33955                 -1.15060
# 6144                      -0.95055                 -0.28000
# 6152                      -1.22630                 -0.54435
# 4735                      -0.28590                  0.24535
# 6233                      -1.06460                 -0.98800
# 6207                      -0.38935                 -0.73755
# 2197                      -1.07560                 -1.02340
# 1072                      -0.03165                 -0.40510
# 6141                      -1.40275                 -0.83650
# 8665                       0.16115                 -0.41070
# 6193                      -2.73780                 -0.62900
# 6155                      -0.24240                 -0.60590
# 6164                      -0.16855                 -0.44165
# 4677                       0.24400                  0.87875
# 56910                     -0.53340                  0.86950
# ...                            ...                      ...
# 55589                     -1.07680                  0.05295
# 376267                    -0.54180                  0.36925
# 55662                     -0.09575                 -0.70495
# 79890                      0.14265                 -1.00465
# 84820                     -0.80700                  1.43585
# 2931                      -0.37600                  0.12305
# 63876                      0.68700                  0.73825
# 5526                      -1.05475                 -0.91085
# 91860                      0.68525                 -1.37810
# 51275                     -0.35460                  0.63730
# 57175                      0.88245                  1.17050
# 126298                     0.10440                  0.33755
# 158747                    -1.26855                 -1.15425
# 64748                      1.09090                 -0.16255
# 78992                      0.59035                  0.00970
# 63897                      0.46570                  0.27005
# 85002                      0.58755                  1.00775
# 283232                     0.33835                 -0.26155
# 25960                     -0.24325                 -0.19920
# 89941                      0.17735                  0.33950
# 79874                      0.83460                 -0.18260
# 100289678                 -0.74770                  0.05570
# 6376                      -0.24395                 -0.38790
# 79716                     -2.46555                  0.22995
# 11033                      0.04355                 -0.29965
# 4034                       0.84320                 -1.23800
# 399664                    -0.43745                  0.07970
# 54869                      0.23405                  0.69485
# 90379                      0.35735                  0.90745
# 60                        -0.54450                 -0.48830
#
# cid        XPR002_YAPC.311_96H:N12
# rid
# 780                        0.13020
# 7849                      -0.25415
# 2978                      -1.09560
# 2049                      -0.20170
# 2101                      -1.05455
# 8717                      -0.04955
# 10594                     -0.23885
# 826                        1.70715
# 11224                      0.37830
# 6158                      -0.01180
# 1982                       0.26825
# 8664                      -0.11805
# 11315                      0.01245
# 6727                       0.62435
# 2665                       0.56045
# 6135                      -0.00995
# 6144                       0.10690
# 6152                      -0.70665
# 4735                       1.04070
# 6233                       0.54470
# 6207                      -0.15340
# 2197                      -1.21165
# 1072                       0.49235
# 6141                      -0.61665
# 8665                       0.32255
# 6193                      -1.41140
# 6155                      -0.07655
# 6164                       0.12760
# 4677                      -0.80360
# 56910                     -0.25285
# ...                            ...
# 55589                     -1.58555
# 376267                     0.18505
# 55662                     -1.32460
# 79890                      1.49685
# 84820                     -0.36415
# 2931                      -0.26845
# 63876                     -0.94640
# 5526                      -1.28285
# 91860                     -0.75975
# 51275                     -1.15750
# 57175                      0.19285
# 126298                     0.00875
# 158747                    -0.25650
# 64748                     -2.52370
# 78992                     -0.73520
# 63897                     -1.29820
# 85002                     -0.19285
# 283232                    -1.53870
# 25960                     -0.52365
# 89941                     -0.81270
# 79874                     -0.44705
# 100289678                  0.13815
# 6376                       0.53070
# 79716                      0.60460
# 11033                     -0.14645
# 4034                       0.06100
# 399664                    -0.37195
# 54869                     -1.41705
# 90379                     -0.32805
# 60                         1.14210
#
# [12328 rows x 3882 columns]

# %%
out_csv = 'expression_data_frame.csv'
gene_only_gctoo.data_df.to_csv(path_or_buf=out_csv)

# %%
import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline

gene_only_gctoo.data_df[gene_only_gctoo.data_df.columns[0]]
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-24-b4c86fc03d48> in <module>()
# ----> 1 import matplotlib
#       2 import matplotlib.pyplot as plt
#       3
#       4 # %matplotlib inline
#       5
#
# /home/nate/bin/anaconda3/envs/cmap/lib/python2.7/site-packages/matplotlib/__init__.py in <module>()
#     122 # cbook must import matplotlib only within function
#     123 # definitions, so it is safe to import from it here.
# --> 124 from . import cbook
#     125 from matplotlib.cbook import (
#     126     _backports, mplDeprecation, dedent, get_label, sanitize_sequence)
#
# ImportError: cannot import name cbook

# %%
gene_ids = pd.read_csv(geneinfopath, sep="\t")
gene_ids[0:2]
# Out:
#    pr_gene_id pr_gene_symbol                                pr_gene_title  \
# 0         780           DDR1  discoidin domain receptor tyrosine kinase 1
# 1        7849           PAX8                                 paired box 8
#
#    pr_is_lm  pr_is_bing
# 0         1           1
# 1         1           1

# %%
column_id = gene_only_gctoo.data_df.idxmax()[0]
gene_ids[gene_ids.pr_gene_id == column_id]
# Out:
#        pr_gene_id pr_gene_symbol                               pr_gene_title  \
# 11788       55620          STAP2  signal transducing adaptor family member 2
#
#        pr_is_lm  pr_is_bing
# 11788         1           1

# %%
sig_id = list(gene_only_gctoo.data_df)[1]
sig_info[sig_info.pert_type == 'trt_xpr'][0:2]
# Out:
#                          sig_id         pert_id pert_iname pert_type  \
# 113871  XPR002_A375.311_96H:A03  BRDN0001054785       AKT2   trt_xpr
# 113872  XPR002_A375.311_96H:A05  BRDN0001055003      CAMK1   trt_xpr
#
#          cell_id pert_idose pert_itime  \
# 113871  A375.311       -666       96 h
# 113872  A375.311       -666       96 h
#
#                                                 distil_id
# 113871  XPR002_A375.311_96H_X1_B21:A03|XPR002_A375.311...
# 113872  XPR002_A375.311_96H_X1_B21:A05|XPR002_A375.311...

# %%
pert_ids = pd.read_csv(pertinfopath, sep="\t")
pert_ids.pert_type.unique()
# Out:
# array(['trt_cp', 'ctl_vehicle', 'trt_xpr', 'ctl_untrt', 'ctl_vector'], dtype=object)

# %%
pert_ids.pert_type.unique()
# Out:
# array(['trt_cp', 'ctl_vehicle', 'trt_xpr', 'ctl_untrt', 'ctl_vector'], dtype=object)

# %%
inst_ids = pd.read_csv(instinfopath, sep="\t")
inst_ids[0:2]
# Out:
#                        inst_id cell_id                det_plate det_well  \
# 0   LJP005_A375_24H_X1_B19:A03    A375   LJP005_A375_24H_X1_B19      A03
# 1  LPROT001_A375_6H_X1_B20:B03    A375  LPROT001_A375_6H_X1_B20      B03
#
#   pert_mfc_id  pert_dose pert_dose_unit pert_id pert_iname    pert_type  \
# 0        DMSO     -666.0           -666    DMSO       DMSO  ctl_vehicle
# 1        DMSO     -666.0           -666    DMSO       DMSO  ctl_vehicle
#
#    pert_time pert_time_unit
# 0       24.0              h
# 1        6.0              h

# %%
inst_ids = pd.read_csv(sigmetricsinfopath, sep="\t")
inst_ids.pert_type.unique()
# Out:
# array(['ctl_vehicle', 'trt_cp', 'trt_xpr', 'ctl_untrt', 'ctl_vector'], dtype=object)
